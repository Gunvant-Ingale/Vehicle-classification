# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip gdrive/My\ Drive/dataset123.zip
# Out:
# Archive:  gdrive/My Drive/dataset123.zip
#    creating: dataset/bicycle/
#   inflating: dataset/bicycle/download (1).jpeg
#   inflating: dataset/bicycle/download (10).jpeg
#   inflating: dataset/bicycle/download (11).jpeg
#   inflating: dataset/bicycle/download (12).jpeg
#   inflating: dataset/bicycle/download (13).jpeg
#   inflating: dataset/bicycle/download (14).jpeg
#   inflating: dataset/bicycle/download (15).jpeg
#   inflating: dataset/bicycle/download (16).jpeg
#   inflating: dataset/bicycle/download (17).jpeg
#   inflating: dataset/bicycle/download (18).jpeg
#   inflating: dataset/bicycle/download (19).jpeg
#   inflating: dataset/bicycle/download (2).jpeg
#   inflating: dataset/bicycle/download (3).jpeg
#   inflating: dataset/bicycle/download (4).jpeg
#   inflating: dataset/bicycle/download (5).jpeg
#   inflating: dataset/bicycle/download (6).jpeg
#   inflating: dataset/bicycle/download (7).jpeg
#   inflating: dataset/bicycle/download (8).jpeg
#   inflating: dataset/bicycle/download (9).jpeg
#   inflating: dataset/bicycle/download.jpeg
#   inflating: dataset/bicycle/images (1).jpeg
#   inflating: dataset/bicycle/images (10).jpeg
#   inflating: dataset/bicycle/images (11).jpeg
#   inflating: dataset/bicycle/images (12).jpeg
#   inflating: dataset/bicycle/images (13).jpeg
#   inflating: dataset/bicycle/images (14).jpeg
#   inflating: dataset/bicycle/images (15).jpeg
#   inflating: dataset/bicycle/images (16).jpeg
#   inflating: dataset/bicycle/images (17).jpeg
#   inflating: dataset/bicycle/images (18).jpeg
#   inflating: dataset/bicycle/images (19).jpeg
#   inflating: dataset/bicycle/images (2).jpeg
#   inflating: dataset/bicycle/images (20).jpeg
#   inflating: dataset/bicycle/images (21).jpeg
#   inflating: dataset/bicycle/images (22).jpeg
#   inflating: dataset/bicycle/images (23).jpeg
#   inflating: dataset/bicycle/images (24).jpeg
#   inflating: dataset/bicycle/images (25).jpeg
#   inflating: dataset/bicycle/images (26).jpeg
#   inflating: dataset/bicycle/images (27).jpeg
#   inflating: dataset/bicycle/images (28).jpeg
#   inflating: dataset/bicycle/images (3).jpeg
#   inflating: dataset/bicycle/images (4).jpeg
#   inflating: dataset/bicycle/images (5).jpeg
#   inflating: dataset/bicycle/images (6).jpeg
#   inflating: dataset/bicycle/images (7).jpeg
#   inflating: dataset/bicycle/images (8).jpeg
#   inflating: dataset/bicycle/images (9).jpeg
#   inflating: dataset/bicycle/images.jpeg
#  extracting: dataset/bicycle/images.png
#    creating: dataset/Bus/
#   inflating: dataset/Bus/download (1).jpeg
#   inflating: dataset/Bus/download (10).jpeg
#   inflating: dataset/Bus/download (11).jpeg
#   inflating: dataset/Bus/download (12).jpeg
#   inflating: dataset/Bus/download (2).jpeg
#   inflating: dataset/Bus/download (3).jpeg
#   inflating: dataset/Bus/download (4).jpeg
#   inflating: dataset/Bus/download (5).jpeg
#   inflating: dataset/Bus/download (6).jpeg
#   inflating: dataset/Bus/download (7).jpeg
#   inflating: dataset/Bus/download (8).jpeg
#   inflating: dataset/Bus/download (9).jpeg
#   inflating: dataset/Bus/download.jpeg
#   inflating: dataset/Bus/images (1).jpeg
#   inflating: dataset/Bus/images (10).jpeg
#   inflating: dataset/Bus/images (11).jpeg
#   inflating: dataset/Bus/images (12).jpeg
#   inflating: dataset/Bus/images (13).jpeg
#   inflating: dataset/Bus/images (14).jpeg
#   inflating: dataset/Bus/images (15).jpeg
#   inflating: dataset/Bus/images (16).jpeg
#   inflating: dataset/Bus/images (17).jpeg
#   inflating: dataset/Bus/images (18).jpeg
#   inflating: dataset/Bus/images (19).jpeg
#   inflating: dataset/Bus/images (2).jpeg
#   inflating: dataset/Bus/images (20).jpeg
#   inflating: dataset/Bus/images (21).jpeg
#   inflating: dataset/Bus/images (22).jpeg
#   inflating: dataset/Bus/images (23).jpeg
#   inflating: dataset/Bus/images (24).jpeg
#   inflating: dataset/Bus/images (25).jpeg
#   inflating: dataset/Bus/images (26).jpeg
#   inflating: dataset/Bus/images (27).jpeg
#   inflating: dataset/Bus/images (28).jpeg
#   inflating: dataset/Bus/images (29).jpeg
#   inflating: dataset/Bus/images (3).jpeg
#   inflating: dataset/Bus/images (30).jpeg
#   inflating: dataset/Bus/images (31).jpeg
#   inflating: dataset/Bus/images (32).jpeg
#   inflating: dataset/Bus/images (33).jpeg
#   inflating: dataset/Bus/images (34).jpeg
#   inflating: dataset/Bus/images (35).jpeg
#   inflating: dataset/Bus/images (36).jpeg
#   inflating: dataset/Bus/images (37).jpeg
#   inflating: dataset/Bus/images (4).jpeg
#   inflating: dataset/Bus/images (5).jpeg
#   inflating: dataset/Bus/images (6).jpeg
#   inflating: dataset/Bus/images (7).jpeg
#   inflating: dataset/Bus/images (8).jpeg
#   inflating: dataset/Bus/images (9).jpeg
#   inflating: dataset/Bus/images.jpeg
#    creating: dataset/convertible/
#   inflating: dataset/convertible/download (1).jpeg
#   inflating: dataset/convertible/download (10).jpeg
#   inflating: dataset/convertible/download (11).jpeg
#   inflating: dataset/convertible/download (12).jpeg
#   inflating: dataset/convertible/download (13).jpeg
#   inflating: dataset/convertible/download (14).jpeg
#   inflating: dataset/convertible/download (15).jpeg
#   inflating: dataset/convertible/download (16).jpeg
#   inflating: dataset/convertible/download (17).jpeg
#   inflating: dataset/convertible/download (18).jpeg
#   inflating: dataset/convertible/download (19).jpeg
#   inflating: dataset/convertible/download (2).jpeg
#   inflating: dataset/convertible/download (3).jpeg
#   inflating: dataset/convertible/download (4).jpeg
#   inflating: dataset/convertible/download (5).jpeg
#   inflating: dataset/convertible/download (6).jpeg
#   inflating: dataset/convertible/download (7).jpeg
#   inflating: dataset/convertible/download (8).jpeg
#   inflating: dataset/convertible/download (9).jpeg
#   inflating: dataset/convertible/download.jpeg
#   inflating: dataset/convertible/images (1).jpeg
#   inflating: dataset/convertible/images (10).jpeg
#   inflating: dataset/convertible/images (11).jpeg
#   inflating: dataset/convertible/images (12).jpeg
#   inflating: dataset/convertible/images (13).jpeg
#   inflating: dataset/convertible/images (14).jpeg
#   inflating: dataset/convertible/images (15).jpeg
#   inflating: dataset/convertible/images (16).jpeg
#   inflating: dataset/convertible/images (17).jpeg
#   inflating: dataset/convertible/images (18).jpeg
#   inflating: dataset/convertible/images (19).jpeg
#   inflating: dataset/convertible/images (2).jpeg
#   inflating: dataset/convertible/images (20).jpeg
#   inflating: dataset/convertible/images (21).jpeg
#   inflating: dataset/convertible/images (22).jpeg
#   inflating: dataset/convertible/images (23).jpeg
#   inflating: dataset/convertible/images (24).jpeg
#   inflating: dataset/convertible/images (25).jpeg
#   inflating: dataset/convertible/images (26).jpeg
#   inflating: dataset/convertible/images (27).jpeg
#   inflating: dataset/convertible/images (28).jpeg
#   inflating: dataset/convertible/images (29).jpeg
#   inflating: dataset/convertible/images (3).jpeg
#   inflating: dataset/convertible/images (30).jpeg
#   inflating: dataset/convertible/images (4).jpeg
#   inflating: dataset/convertible/images (5).jpeg
#   inflating: dataset/convertible/images (6).jpeg
#   inflating: dataset/convertible/images (7).jpeg
#   inflating: dataset/convertible/images (8).jpeg
#   inflating: dataset/convertible/images (9).jpeg
#   inflating: dataset/convertible/images.jpeg
#    creating: dataset/Motorcycle/
#   inflating: dataset/Motorcycle/download (1).jpeg
#   inflating: dataset/Motorcycle/download (10).jpeg
#   inflating: dataset/Motorcycle/download (11).jpeg
#   inflating: dataset/Motorcycle/download (13).jpeg
#   inflating: dataset/Motorcycle/download (2).jpeg
#   inflating: dataset/Motorcycle/download (3).jpeg
#   inflating: dataset/Motorcycle/download (4).jpeg
#   inflating: dataset/Motorcycle/download (5).jpeg
#   inflating: dataset/Motorcycle/download (6).jpeg
#   inflating: dataset/Motorcycle/download (7).jpeg
#   inflating: dataset/Motorcycle/download (8).jpeg
#   inflating: dataset/Motorcycle/download (9).jpeg
#   inflating: dataset/Motorcycle/download.jpeg
#   inflating: dataset/Motorcycle/images (1).jpeg
#   inflating: dataset/Motorcycle/images (10).jpeg
#   inflating: dataset/Motorcycle/images (11).jpeg
#   inflating: dataset/Motorcycle/images (12).jpeg
#   inflating: dataset/Motorcycle/images (13).jpeg
#   inflating: dataset/Motorcycle/images (14).jpeg
#   inflating: dataset/Motorcycle/images (15).jpeg
#   inflating: dataset/Motorcycle/images (16).jpeg
#   inflating: dataset/Motorcycle/images (17).jpeg
#   inflating: dataset/Motorcycle/images (18).jpeg
#   inflating: dataset/Motorcycle/images (19).jpeg
#   inflating: dataset/Motorcycle/images (2).jpeg
#   inflating: dataset/Motorcycle/images (20).jpeg
#   inflating: dataset/Motorcycle/images (21).jpeg
#   inflating: dataset/Motorcycle/images (22).jpeg
#   inflating: dataset/Motorcycle/images (23).jpeg
#   inflating: dataset/Motorcycle/images (24).jpeg
#   inflating: dataset/Motorcycle/images (25).jpeg
#   inflating: dataset/Motorcycle/images (26).jpeg
#   inflating: dataset/Motorcycle/images (27).jpeg
#   inflating: dataset/Motorcycle/images (28).jpeg
#   inflating: dataset/Motorcycle/images (29).jpeg
#   inflating: dataset/Motorcycle/images (3).jpeg
#   inflating: dataset/Motorcycle/images (30).jpeg
#   inflating: dataset/Motorcycle/images (31).jpeg
#   inflating: dataset/Motorcycle/images (32).jpeg
#   inflating: dataset/Motorcycle/images (33).jpeg
#   inflating: dataset/Motorcycle/images (34).jpeg
#   inflating: dataset/Motorcycle/images (35).jpeg
#   inflating: dataset/Motorcycle/images (36).jpeg
#   inflating: dataset/Motorcycle/images (37).jpeg
#   inflating: dataset/Motorcycle/images (38).jpeg
#   inflating: dataset/Motorcycle/images (39).jpeg
#   inflating: dataset/Motorcycle/images (4).jpeg
#   inflating: dataset/Motorcycle/images (40).jpeg
#   inflating: dataset/Motorcycle/images (5).jpeg
#   inflating: dataset/Motorcycle/images (6).jpeg
#   inflating: dataset/Motorcycle/images (7).jpeg
#   inflating: dataset/Motorcycle/images (8).jpeg
#   inflating: dataset/Motorcycle/images (9).jpeg
#   inflating: dataset/Motorcycle/images.jpeg
#    creating: dataset/Sedan/
#   inflating: dataset/Sedan/download (1).jpeg
#   inflating: dataset/Sedan/download (10).jpeg
#   inflating: dataset/Sedan/download (11).jpeg
#   inflating: dataset/Sedan/download (12).jpeg
#   inflating: dataset/Sedan/download (2).jpeg
#   inflating: dataset/Sedan/download (3).jpeg
#   inflating: dataset/Sedan/download (4).jpeg
#   inflating: dataset/Sedan/download (5).jpeg
#   inflating: dataset/Sedan/download (6).jpeg
#   inflating: dataset/Sedan/download (7).jpeg
#   inflating: dataset/Sedan/download (8).jpeg
#   inflating: dataset/Sedan/download (9).jpeg
#   inflating: dataset/Sedan/download.jpeg
#   inflating: dataset/Sedan/images (1).jpeg
#   inflating: dataset/Sedan/images (10).jpeg
#   inflating: dataset/Sedan/images (11).jpeg
#   inflating: dataset/Sedan/images (12).jpeg
#   inflating: dataset/Sedan/images (13).jpeg
#   inflating: dataset/Sedan/images (14).jpeg
#  extracting: dataset/Sedan/images (15).jpeg
#   inflating: dataset/Sedan/images (16).jpeg
#   inflating: dataset/Sedan/images (17).jpeg
#   inflating: dataset/Sedan/images (18).jpeg
#   inflating: dataset/Sedan/images (19).jpeg
#   inflating: dataset/Sedan/images (2).jpeg
#   inflating: dataset/Sedan/images (20).jpeg
#   inflating: dataset/Sedan/images (21).jpeg
#   inflating: dataset/Sedan/images (22).jpeg
#   inflating: dataset/Sedan/images (23).jpeg
#   inflating: dataset/Sedan/images (24).jpeg
#   inflating: dataset/Sedan/images (25).jpeg
#   inflating: dataset/Sedan/images (26).jpeg
#   inflating: dataset/Sedan/images (27).jpeg
#   inflating: dataset/Sedan/images (28).jpeg
#   inflating: dataset/Sedan/images (29).jpeg
#   inflating: dataset/Sedan/images (3).jpeg
#   inflating: dataset/Sedan/images (30).jpeg
#   inflating: dataset/Sedan/images (31).jpeg
#   inflating: dataset/Sedan/images (32).jpeg
#   inflating: dataset/Sedan/images (33).jpeg
#   inflating: dataset/Sedan/images (34).jpeg
#   inflating: dataset/Sedan/images (35).jpeg
#   inflating: dataset/Sedan/images (36).jpeg
#   inflating: dataset/Sedan/images (37).jpeg
#   inflating: dataset/Sedan/images (38).jpeg
#   inflating: dataset/Sedan/images (39).jpeg
#   inflating: dataset/Sedan/images (4).jpeg
#   inflating: dataset/Sedan/images (40).jpeg
#   inflating: dataset/Sedan/images (5).jpeg
#   inflating: dataset/Sedan/images (6).jpeg
#   inflating: dataset/Sedan/images (7).jpeg
#   inflating: dataset/Sedan/images (8).jpeg
#   inflating: dataset/Sedan/images (9).jpeg
#   inflating: dataset/Sedan/images.jpeg
#    creating: dataset/sports car/
#   inflating: dataset/sports car/download (1).jpeg
#   inflating: dataset/sports car/download (10).jpeg
#   inflating: dataset/sports car/download (11).jpeg
#   inflating: dataset/sports car/download (2).jpeg
#   inflating: dataset/sports car/download (20).jpeg
#   inflating: dataset/sports car/download (3).jpeg
#   inflating: dataset/sports car/download (4).jpeg
#   inflating: dataset/sports car/download (5).jpeg
#   inflating: dataset/sports car/download (6).jpeg
#   inflating: dataset/sports car/download (7).jpeg
#   inflating: dataset/sports car/download (8).jpeg
#   inflating: dataset/sports car/download (9).jpeg
#   inflating: dataset/sports car/download.jpeg
#   inflating: dataset/sports car/images (1).jpeg
#   inflating: dataset/sports car/images (10).jpeg
#   inflating: dataset/sports car/images (11).jpeg
#   inflating: dataset/sports car/images (12).jpeg
#   inflating: dataset/sports car/images (13).jpeg
#   inflating: dataset/sports car/images (14).jpeg
#   inflating: dataset/sports car/images (15).jpeg
#   inflating: dataset/sports car/images (16).jpeg
#   inflating: dataset/sports car/images (17).jpeg
#   inflating: dataset/sports car/images (18).jpeg
#   inflating: dataset/sports car/images (19).jpeg
#   inflating: dataset/sports car/images (2).jpeg
#   inflating: dataset/sports car/images (20).jpeg
#   inflating: dataset/sports car/images (21).jpeg
#   inflating: dataset/sports car/images (22).jpeg
#   inflating: dataset/sports car/images (23).jpeg
#   inflating: dataset/sports car/images (24).jpeg
#   inflating: dataset/sports car/images (25).jpeg
#   inflating: dataset/sports car/images (26).jpeg
#   inflating: dataset/sports car/images (27).jpeg
#   inflating: dataset/sports car/images (28).jpeg
#   inflating: dataset/sports car/images (29).jpeg
#   inflating: dataset/sports car/images (3).jpeg
#   inflating: dataset/sports car/images (30).jpeg
#   inflating: dataset/sports car/images (31).jpeg
#   inflating: dataset/sports car/images (32).jpeg
#   inflating: dataset/sports car/images (33).jpeg
#   inflating: dataset/sports car/images (34).jpeg
#   inflating: dataset/sports car/images (35).jpeg
#   inflating: dataset/sports car/images (36).jpeg
#   inflating: dataset/sports car/images (4).jpeg
#   inflating: dataset/sports car/images (5).jpeg
#   inflating: dataset/sports car/images (6).jpeg
#   inflating: dataset/sports car/images (7).jpeg
#   inflating: dataset/sports car/images (8).jpeg
#   inflating: dataset/sports car/images (9).jpeg
#   inflating: dataset/sports car/images.jpeg
#    creating: dataset/SUV/
#   inflating: dataset/SUV/download (1).jpeg
#   inflating: dataset/SUV/download (2).jpeg
#   inflating: dataset/SUV/download.jpeg
#   inflating: dataset/SUV/images (1).jpeg
#   inflating: dataset/SUV/images (10).jpeg
#   inflating: dataset/SUV/images (11).jpeg
#   inflating: dataset/SUV/images (12).jpeg
#   inflating: dataset/SUV/images (13).jpeg
#   inflating: dataset/SUV/images (14).jpeg
#   inflating: dataset/SUV/images (15).jpeg
#   inflating: dataset/SUV/images (16).jpeg
#   inflating: dataset/SUV/images (17).jpeg
#   inflating: dataset/SUV/images (18).jpeg
#   inflating: dataset/SUV/images (19).jpeg
#   inflating: dataset/SUV/images (2).jpeg
#   inflating: dataset/SUV/images (20).jpeg
#   inflating: dataset/SUV/images (21).jpeg
#   inflating: dataset/SUV/images (22).jpeg
#   inflating: dataset/SUV/images (23).jpeg
#   inflating: dataset/SUV/images (24).jpeg
#   inflating: dataset/SUV/images (25).jpeg
#   inflating: dataset/SUV/images (26).jpeg
#  extracting: dataset/SUV/images (27).jpeg
#   inflating: dataset/SUV/images (28).jpeg
#   inflating: dataset/SUV/images (29).jpeg
#   inflating: dataset/SUV/images (3).jpeg
#   inflating: dataset/SUV/images (30).jpeg
#   inflating: dataset/SUV/images (31).jpeg
#   inflating: dataset/SUV/images (32).jpeg
#   inflating: dataset/SUV/images (33).jpeg
#   inflating: dataset/SUV/images (34).jpeg
#   inflating: dataset/SUV/images (35).jpeg
#   inflating: dataset/SUV/images (36).jpeg
#   inflating: dataset/SUV/images (37).jpeg
#   inflating: dataset/SUV/images (38).jpeg
#   inflating: dataset/SUV/images (39).jpeg
#   inflating: dataset/SUV/images (4).jpeg
#   inflating: dataset/SUV/images (40).jpeg
#   inflating: dataset/SUV/images (41).jpeg
#   inflating: dataset/SUV/images (42).jpeg
#   inflating: dataset/SUV/images (43).jpeg
#   inflating: dataset/SUV/images (44).jpeg
#   inflating: dataset/SUV/images (45).jpeg
#   inflating: dataset/SUV/images (46).jpeg
#   inflating: dataset/SUV/images (47).jpeg
#   inflating: dataset/SUV/images (48).jpeg
#   inflating: dataset/SUV/images (49).jpeg
#   inflating: dataset/SUV/images (5).jpeg
#   inflating: dataset/SUV/images (6).jpeg
#   inflating: dataset/SUV/images (7).jpeg
#   inflating: dataset/SUV/images (8).jpeg
#   inflating: dataset/SUV/images (9).jpeg
#   inflating: dataset/SUV/images.jpeg
#    creating: dataset/threewheeler/
#   inflating: dataset/threewheeler/download (1).jpeg
#   inflating: dataset/threewheeler/download (10).jpeg
#   inflating: dataset/threewheeler/download (11).jpeg
#   inflating: dataset/threewheeler/download (12).jpeg
#   inflating: dataset/threewheeler/download (13).jpeg
#   inflating: dataset/threewheeler/download (14).jpeg
#   inflating: dataset/threewheeler/download (2).jpeg
#   inflating: dataset/threewheeler/download (3).jpeg
#   inflating: dataset/threewheeler/download (4).jpeg
#   inflating: dataset/threewheeler/download (5).jpeg
#   inflating: dataset/threewheeler/download (6).jpeg
#   inflating: dataset/threewheeler/download (7).jpeg
#   inflating: dataset/threewheeler/download (8).jpeg
#   inflating: dataset/threewheeler/download (9).jpeg
#   inflating: dataset/threewheeler/download.jpeg
#   inflating: dataset/threewheeler/images (1).jpeg
#   inflating: dataset/threewheeler/images (10).jpeg
#   inflating: dataset/threewheeler/images (11).jpeg
#   inflating: dataset/threewheeler/images (12).jpeg
#   inflating: dataset/threewheeler/images (13).jpeg
#   inflating: dataset/threewheeler/images (14).jpeg
#   inflating: dataset/threewheeler/images (15).jpeg
#   inflating: dataset/threewheeler/images (16).jpeg
#   inflating: dataset/threewheeler/images (17).jpeg
#   inflating: dataset/threewheeler/images (18).jpeg
#   inflating: dataset/threewheeler/images (19).jpeg
#   inflating: dataset/threewheeler/images (2).jpeg
#   inflating: dataset/threewheeler/images (20).jpeg
#   inflating: dataset/threewheeler/images (21).jpeg
#   inflating: dataset/threewheeler/images (22).jpeg
#   inflating: dataset/threewheeler/images (23).jpeg
#   inflating: dataset/threewheeler/images (24).jpeg
#   inflating: dataset/threewheeler/images (25).jpeg
#   inflating: dataset/threewheeler/images (26).jpeg
#   inflating: dataset/threewheeler/images (27).jpeg
#   inflating: dataset/threewheeler/images (28).jpeg
#   inflating: dataset/threewheeler/images (29).jpeg
#   inflating: dataset/threewheeler/images (3).jpeg
#   inflating: dataset/threewheeler/images (30).jpeg
#   inflating: dataset/threewheeler/images (31).jpeg
#   inflating: dataset/threewheeler/images (32).jpeg
#   inflating: dataset/threewheeler/images (33).jpeg
#   inflating: dataset/threewheeler/images (34).jpeg
#   inflating: dataset/threewheeler/images (4).jpeg
#   inflating: dataset/threewheeler/images (5).jpeg
#   inflating: dataset/threewheeler/images (6).jpeg
#   inflating: dataset/threewheeler/images (7).jpeg
#   inflating: dataset/threewheeler/images (8).jpeg
#   inflating: dataset/threewheeler/images (9).jpeg
#   inflating: dataset/threewheeler/images.jpeg
#    creating: dataset/Truck/
#   inflating: dataset/Truck/download (1).jpeg
#   inflating: dataset/Truck/download (10).jpeg
#   inflating: dataset/Truck/download (11).jpeg
#   inflating: dataset/Truck/download (2).jpeg
#   inflating: dataset/Truck/download (3).jpeg
#   inflating: dataset/Truck/download (4).jpeg
#   inflating: dataset/Truck/download (5).jpeg
#   inflating: dataset/Truck/download (6).jpeg
#   inflating: dataset/Truck/download (7).jpeg
#   inflating: dataset/Truck/download (8).jpeg
#   inflating: dataset/Truck/download (9).jpeg
#   inflating: dataset/Truck/download.jpeg
#   inflating: dataset/Truck/images (1).jpeg
#   inflating: dataset/Truck/images (10).jpeg
#   inflating: dataset/Truck/images (11).jpeg
#   inflating: dataset/Truck/images (12).jpeg
#   inflating: dataset/Truck/images (13).jpeg
#   inflating: dataset/Truck/images (14).jpeg
#   inflating: dataset/Truck/images (15).jpeg
#   inflating: dataset/Truck/images (16).jpeg
#   inflating: dataset/Truck/images (17).jpeg
#   inflating: dataset/Truck/images (18).jpeg
#   inflating: dataset/Truck/images (19).jpeg
#   inflating: dataset/Truck/images (2).jpeg
#   inflating: dataset/Truck/images (20).jpeg
#   inflating: dataset/Truck/images (21).jpeg
#   inflating: dataset/Truck/images (22).jpeg
#   inflating: dataset/Truck/images (23).jpeg
#   inflating: dataset/Truck/images (24).jpeg
#   inflating: dataset/Truck/images (25).jpeg
#   inflating: dataset/Truck/images (26).jpeg
#   inflating: dataset/Truck/images (27).jpeg
#   inflating: dataset/Truck/images (28).jpeg
#   inflating: dataset/Truck/images (29).jpeg
#   inflating: dataset/Truck/images (3).jpeg
#   inflating: dataset/Truck/images (30).jpeg
#   inflating: dataset/Truck/images (31).jpeg
#   inflating: dataset/Truck/images (32).jpeg
#   inflating: dataset/Truck/images (33).jpeg
#   inflating: dataset/Truck/images (34).jpeg
#   inflating: dataset/Truck/images (35).jpeg
#   inflating: dataset/Truck/images (36).jpeg
#   inflating: dataset/Truck/images (37).jpeg
#  extracting: dataset/Truck/images (38).jpeg
#   inflating: dataset/Truck/images (39).jpeg
#   inflating: dataset/Truck/images (4).jpeg
#   inflating: dataset/Truck/images (5).jpeg
#   inflating: dataset/Truck/images (6).jpeg
#   inflating: dataset/Truck/images (7).jpeg
#   inflating: dataset/Truck/images (8).jpeg
#   inflating: dataset/Truck/images (9).jpeg
#   inflating: dataset/Truck/images.jpeg
#    creating: dataset/Van/
#   inflating: dataset/Van/download (1).jpeg
#   inflating: dataset/Van/download (10).jpeg
#   inflating: dataset/Van/download (11).jpeg
#   inflating: dataset/Van/download (12).jpeg
#   inflating: dataset/Van/download (13).jpeg
#   inflating: dataset/Van/download (14).jpeg
#   inflating: dataset/Van/download (15).jpeg
#   inflating: dataset/Van/download (16).jpeg
#   inflating: dataset/Van/download (17).jpeg
#   inflating: dataset/Van/download (18).jpeg
#   inflating: dataset/Van/download (2).jpeg
#   inflating: dataset/Van/download (20).jpeg
#   inflating: dataset/Van/download (3).jpeg
#   inflating: dataset/Van/download (4).jpeg
#   inflating: dataset/Van/download (5).jpeg
#   inflating: dataset/Van/download (6).jpeg
#   inflating: dataset/Van/download (7).jpeg
#   inflating: dataset/Van/download (8).jpeg
#   inflating: dataset/Van/download (9).jpeg
#   inflating: dataset/Van/download.jpeg
#   inflating: dataset/Van/images (1).jpeg
#   inflating: dataset/Van/images (10).jpeg
#   inflating: dataset/Van/images (11).jpeg
#   inflating: dataset/Van/images (12).jpeg
#   inflating: dataset/Van/images (13).jpeg
#   inflating: dataset/Van/images (14).jpeg
#   inflating: dataset/Van/images (15).jpeg
#   inflating: dataset/Van/images (16).jpeg
#   inflating: dataset/Van/images (17).jpeg
#   inflating: dataset/Van/images (18).jpeg
#   inflating: dataset/Van/images (19).jpeg
#   inflating: dataset/Van/images (2).jpeg
#   inflating: dataset/Van/images (20).jpeg
#   inflating: dataset/Van/images (21).jpeg
#   inflating: dataset/Van/images (22).jpeg
#   inflating: dataset/Van/images (23).jpeg
#   inflating: dataset/Van/images (24).jpeg
#   inflating: dataset/Van/images (25).jpeg
#   inflating: dataset/Van/images (26).jpeg
#   inflating: dataset/Van/images (27).jpeg
#   inflating: dataset/Van/images (28).jpeg
#   inflating: dataset/Van/images (29).jpeg
#   inflating: dataset/Van/images (3).jpeg
#   inflating: dataset/Van/images (30).jpeg
#   inflating: dataset/Van/images (31).jpeg
#   inflating: dataset/Van/images (32).jpeg
#   inflating: dataset/Van/images (33).jpeg
#   inflating: dataset/Van/images (4).jpeg
#   inflating: dataset/Van/images (5).jpeg
#   inflating: dataset/Van/images (6).jpeg
#   inflating: dataset/Van/images (7).jpeg
#   inflating: dataset/Van/images (8).jpeg
#   inflating: dataset/Van/images (9).jpeg
#   inflating: dataset/Van/images.jpeg

# %%
# !ls dataset
# Out:
#  bicycle   convertible	 Sedan	       SUV	      Truck
#  Bus	   Motorcycle	'sports car'   threewheeler   Van

# %%
import os

num_skipped = 0
for folder_name in ("bicycle","convertible",	 "Sedan",  "SUV", "Truck", "Bus"	,   "Motorcycle",	"sports car"  , "threewheeler",  "Van"):
    folder_path = os.path.join("dataset", folder_name)
    for fname in os.listdir(folder_path):
        fpath = os.path.join(folder_path, fname)
        try:
            fobj = open(fpath, "rb")
            is_jfif = tf.compat.as_bytes("JFIF") in fobj.peek(10)
        finally:
            fobj.close()

        if not is_jfif:
            num_skipped += 1
            # Delete corrupted image
            os.remove(fpath)

print("Deleted %d images" % num_skipped)
# Out:
# Deleted 1 images

# %%
image_size = (180, 180)
batch_size = 128

train_ds, val_ds = tf.keras.utils.image_dataset_from_directory(
    "dataset",
    validation_split=0.2,
    subset="both",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 518 files belonging to 10 classes.
# Using 415 files for training.
# Using 103 files for validation.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
    ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %%
augmented_train_ds = train_ds.map(
    lambda x, y: (data_augmentation(x, training=True), y))

# %%
# Apply `data_augmentation` to the training images.
train_ds = train_ds.map(
    lambda img, label: (data_augmentation(img), label),
    num_parallel_calls=tf.data.AUTOTUNE,
)
# Prefetching samples in GPU memory helps maximize GPU utilization.
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.prefetch(tf.data.AUTOTUNE)

# %%
def make_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)

    # Entry block
    x = layers.Rescaling(1.0 / 255)(inputs)
    x = layers.Conv2D(128, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    for size in [256, 512, 728]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.GlobalAveragePooling2D()(x)
    if num_classes == 2:
        activation = "sigmoid"
        units = 1
    else:
        activation = "softmax"
        units = num_classes

    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(units, activation=activation)(x)
    return keras.Model(inputs, outputs)


model = make_model(input_shape=image_size + (3,), num_classes=2)
keras.utils.plot_model(model, show_shapes=True)

# %%
epochs = 25

callbacks = [
    keras.callbacks.ModelCheckpoint("save_at_{epoch}.keras"),
]
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train_ds,
    epochs=epochs,
    callbacks=callbacks,
    validation_data=val_ds,
)
